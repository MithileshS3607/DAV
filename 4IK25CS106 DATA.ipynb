# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Order Data": [
        "2024-01-10",
        "2024-01-15",
        "2024-02-05",
        "2024-02-12",
        "2024-03-01",
        "2024-03-15",
        "2024-04-10",
        "2024-04-20", 
        "2024-05-05",
        "2024-01-15",
    ],
    "Prodeuct Name" : [
        "Laptop",
        "Mouse",
        "Printer",
        "Tablet",
        "Laptop",
        "Monitor",
        "Mouse",
        "Printer"
        "Smartwatch",
        "Mouse",
    ],
    "Category" : [
        "Electronics",
        "Acessories",
        "Office",
        "Electronics",
        "Electronics",
        "Accessories",
        "Accessories",
        "Office",
        "Electronics",
        "Accessories",
    ],
    "Region" : [
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",  
    ],
    "Quantity" : [
        2,
        5,
        3,
        4,
        1,
        2,
        6,
        2,
        3,
        5,
    ],
    "Sales" : [
        50000,
        2500,
        9000,
        30000,
        55000,
        16000,
        3000,
        6000,
        45000,
        2500,
    ],
    "Profit": [
        10000,
        500,
        1500,
        6000,
        1100,
        3000,
        None,
        1000,
        9000,
        500,
    ],
})

# %%
print("6.DESCRIPIVE STATISTICS")
print("-" * 50)
print(df.describe())
# Out:
# 6.DESCRIPIVE STATISTICS
# --------------------------------------------------
#         Quantity         Sales        Profit
# count  10.000000     10.000000      9.000000
# mean    3.300000  21900.000000   3622.222222
# std     1.636392  21209.012759   3756.254044
# min     1.000000   2500.000000    500.000000
# 25%     2.000000   3750.000000   1000.000000
# 50%     3.000000  12500.000000   1500.000000
# 75%     4.750000  41250.000000   6000.000000
# max     6.000000  55000.000000  10000.000000

# %%
print("7. MISSING VALUES")
print("-" * 50)
print(df.isnull().sum())
# Out:
# 7. MISSING VALUES
# --------------------------------------------------
# Order Data       0
# Prodeuct Name    0
# Category         0
# Region           0
# Quantity         0
# Sales            0
# Profit           1
# dtype: int64

# %%
print("8. ROWS CONTAINIG MISSING VALUES")
print("-" * 50)
display(df[df.isnull().any(axis=1)])
# Out:
# 8. ROWS CONTAINIG MISSING VALUES
# --------------------------------------------------
#    Order Data Prodeuct Name     Category Region  Quantity  Sales  Profit
# 6  2024-04-10         Mouse  Accessories   East         6   3000     NaN

# %%
print("9. TOTAL DUPLICATE RECORDS ")
print("-" *50)
print(df.duplicated().sum())
# Out:
# 9. TOTAL DUPLICATE RECORDS
# --------------------------------------------------
# 0
